# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\muham\appdata\roaming\python\python312\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muham\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\muham\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Basic Plot

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.show()

# %% [markdown]
# Plot Custoizations

# %%
plt.plot(x, y, color='green', linestyle='--', marker='o')
plt.title('My Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# Multiple Lines

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [1, 2, 3]
plt.plot(x, y1, label='Squares')
plt.plot(x, y2, label='Linear')
plt.legend()
plt.show()

# %% [markdown]
# Bar Chart

# %%
categories = ['A', 'B', 'C']
values = [5, 7, 3]
plt.bar(categories, values)
plt.show()

# %% [markdown]
# Histogram

# %%
data = [1, 1, 2, 3, 3, 3, 4, 4, 5]
plt.hist(data, bins=5)
plt.show()

# %% [markdown]
# Scatter Plot

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Subplots

# %%
plt.subplot(1, 2, 1)
plt.plot([1, 2, 3], [1, 2, 3])
plt.subplot(1, 2, 2)
plt.plot([1, 2, 3], [3, 2, 1])
plt.show()

# %% [markdown]
# Saving figures

# %%
plt.plot(x, y)
plt.savefig('plot.png')
