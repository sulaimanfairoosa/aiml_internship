# %%
numbers = {10,20,30,40,50}
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
cities = {"mumbai","chennai"}
cities.add("delhi")
print(cities)
# Out:
# {'mumbai', 'delhi', 'chennai'}

# %%
subject = {"maths","science","english"}
subject.remove("science")
print(subject)
# Out:
# {'maths', 'english'}

# %%
numbers = {10,20,30,40,50}
print(50 in numbers)
# Out:
# True

# %%
set1 = {1,2,3}
set2 = {3,4,5}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %%
brands = {"samsung","vivo","oppo","realme"}
print(len(brands))
# Out:
# 4

# %%
number = {1,2,3,4}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
numbers = {10,20,30}
numbers.update([40,50,60])
print(numbers)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
numbers = [1,2,2,3,3,4]
result = set(numbers)
print(result)
# Out:
# {1, 2, 3, 4}
