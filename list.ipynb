# %%
# To create a list of 5 subject names and print the 1st subject
subject = ["Maths","Science","English","Physics","Chemistry"]
print(subject[0])
# Out:
# Maths

# %%
# To create a list of numbers and print the last element
numbers = [10,20,30,40,50]
print(numbers[-1])
# Out:
# 50

# %%
# To create a list of mobile brands and add new brand
brands = ["Samsung","Apple","Vivo"]
brands.append("Oneplus")
print(brands)
# Out:
# ['Samsung', 'Apple', 'Vivo', 'Oneplus']

# %%
# To store 5 students names in a list and print the total number of names
students = ["Alen","Adhil","Amal","Vaishnav","Karthik"]
print(len(students))
# Out:
# 5

# %%
# To create a list [10,20,30,40] and change 30 to 35
nums=[10,20,30,40]
nums[2]=35
print(nums)
# Out:
# [10, 20, 35, 40]

# %%
# To Remove "maths" from the list ["science","maths","english"]
subjects2= ["science","maths","english"]
subjects2.remove("maths")
print(subjects2)
# Out:
# ['science', 'english']

# %%
# To create a list of number and print the maximum value
values=[12,45,67,23,89]
print(max(values))
# Out:
# 89

# %%
# To store 5 city names in a list and print them in alphebetical order
cities = ["delhi","mumbai","kochi","chennai","banglore"]
cities.sort()
print(cities)
# Out:
# ['banglore', 'chennai', 'delhi', 'kochi', 'mumbai']

# %%
#combain two lists
list1 =[1, 2, 3]
list2 = [4, 5, 6]
combained = list1 + list2
print(combained)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# check whether "pen" exixts in the list
items = ["book","pen","pencil"]
if "pen" in items:
    print("pen exists in the list")
else:
    print("pen does not exist in the list")
# Out:
# pen exists in the list

# %%
# To create a 5 cities to print a
