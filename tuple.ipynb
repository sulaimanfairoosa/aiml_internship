# %%
numbers = (10,20,30,40,50,)
print(numbers[0])
# Out:
# 10

# %%
students = ("arun","rahul","sneha","anu")
print(students[-1])
# Out:
# anu

# %%
numbers = (10,20,30,40)
print(len(numbers))
# Out:
# 4

# %%
countries = ("india","usa","japan","china","brazil")
print("india"in countries)
# Out:
# True

# %%
numbers = (12,45,67,23,89)
print(max(numbers))
# Out:
# 89

# %%
numbers = (1,5,2,5,3)
print (numbers.count(5))
# Out:
# 2

# %%
tuple1 = (1,2)
tuple2 = (3,4)
result = tuple1 + tuple2
print(result)
# Out:
# (1, 2, 3, 4)

# %%
animals = ("tiger","dog","elephent","cat")
print(sorted(animals))
# Out:
# ['cat', 'dog', 'elephent', 'tiger']

# %%
languages = ("python","java","c++")
print(languages.index("java"))
# Out:
# 1

# %%
number = (10,20,30,)
result = list(numbers)
print(result)
# Out:
# [1, 5, 2, 5, 3]
