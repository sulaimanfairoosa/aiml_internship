# %%
person={"name":"vaishnav","age":20}
print(person["name"])
print(person["age"])
# Out:
# vaishnav
# 20

# %%
student={"names":"rahul","class":10,"mark":95}
print(student["names"])
# Out:
# rahul

# %%
marks={"maths":90,"science":85,"english":88}
print(marks.keys())
# Out:
# dict_keys(['maths', 'science', 'english'])

# %%
d={"name":"anu"}
d["city"]="kochi"
print(d)
# Out:
# {'name': 'anu', 'city': 'kochi'}

# %%
d={"a":10,"b":20}
d["b"]=50
print(d)
# Out:
# {'a': 10, 'b': 50}

# %%
d={"name":"akhil","age":21}
d.pop("age")
print(d)
# Out:
# {'name': 'akhil'}

# %%
employee={"names":"arun","salary":50000,"city":"delhi"}
print(employee.values())
# Out:
# dict_values(['arun', 50000, 'delhi'])

# %%
d={"name":"ravi","salary":40000}
print("salary"in d)
# Out:
# True

# %%
d1={"a":1}
d2={"b":2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
d={"a":1,"b":2,"c":3}
print(len(d))
# Out:
# 3
