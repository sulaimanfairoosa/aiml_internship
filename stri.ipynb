# %%
x=5

# %%
x
# Out:
# 5

# %%
# single word
my_first_string='alen,amal,vaishnav,adhil'
my_first_string
print(my_first_string)
# Out:
# alen,amal,vaishnav,adhil

# %%
# entire phrase
phrase = 'Strings are used to record text information'
print(phrase)
# Out:
# Strings are used to record text information

# %%
#statement to get the type of the variable
type(phrase)
# Out:
# str

# %%
#We can also use double quotes
my_string ="string built with double quotes"
print(my_string) #use the print command
# Out:
# string built with double quotes

# %%
#Be careful with quotes!
sentence= 'i'm using single quotes, but this will create an error'
print(sentence)
# Out:
#   Cell In[63], line 2
#     sentence= 'i'm using single quotes, but this will create an error'
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#Be careful with quotes!
sentence= "i'm using single quotes, but this will create an error"
print(sentence)
# Out:
# i'm using single quotes, but this will create an error

# %%
hash = '#'
print(hash)
# Out:
# #

# %%
type(hash)
# Out:
# str

# %%
# We can simply declare a string
'Deep Learning'
# Out:
# 'Deep Learning'

# %%
# Note that we can't output multiple strings this way
'Linear Algebra'
'Calculus'
# Out:
# 'Calculus'

# %%
print('Linear Algebra')
print('Calculus')
print('Use \n to print a new line')
print('\n')
print('See what \n I mean?')
# Out:
# Linear Algebra
# Calculus
# Use
#  to print a new line
#
#
# See what
#  I mean?

# %%
algo = ' Regres sion'
len(algo)
# Out:
# 12

# %%
#Assign string as a string
string = ' principal componet analysis!'

# %%
#Print the object
print(string)
# Out:
# principal componet analysis!

# %%
print(string[0])
# Out:
# p

# %%
print(string[1])
# Out:
# r

# %%
#Show first element (in this case a letter)
print(string[5])
# Out:
# i

# %%
print(string[15])
# Out:
# n

# %%
len(string)
# Out:
# 29

# %%
#Grab the element at the index -1, which is the LAST element
print(string[28])
# Out:
# !

# %%
print(string[-1])
# Out:
# !

# %%
print(string[-2])
# Out:
# s
