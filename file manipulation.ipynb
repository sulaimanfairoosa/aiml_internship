# %% [markdown]
# Reading from a file

# %%
f = open("example.txt", "r") # Open file in read mode
content = f.read() # Read entire file
print(content)
f.close()
# Out:
# Hello, fairoosa,file Handling!
# This is an additional line.

# %% [markdown]
# Writing to a file

# %%
f = open("example.txt", "w") #opens the file in write mode
f.write("Hello, fairoosa,file Handling!") 
f.close()

# %% [markdown]
# Appending to a file

# %%
f = open("example.txt", "a") #open file in append mode
f.write("\nThis is an additional line.")
f.close()

# %%
try:
    num = int("abc") # This will raise a ValueError
              
except ValueError:
    print("Invalid input! Please enter a number.")
else:
    print("No Error")
# Out:
# Invalid input! Please enter a number.

# %% [markdown]
# Catching Specific Exception Type

# %%
try:
    result = int("100a")
    #result = 10 / 0

except ZeroDivisionError:
    print("Division by zero is not allowed.")
#except ValueError:
#   print("Invalid value.")
except Exception as e: # Catching any other unexpected exceptions
    print(f"An unexpected error occurred: {e}")
# Out:
# An unexpected error occurred: invalid literal for int() with base 10: '100a'

# %% [markdown]
# finally Statement

# %%
try:
    file = open("sample.txt", "w")
    file.write("Hello")
    #print(1 / 0) # Will raise ZeroDivisionError
except ZeroDivisionError:
    print("Cannot divide by zero.")
else:
    print("No Error")
finally:
    file.close()
    print("File closed.")
# Out:
# No Error
# File closed.

# %% [markdown]
# Combined Example

# %%
try:
    num = int(input("Enter a number: "))
    assert num != 0, "Number cannot be zero."
    result = 10 / num
except ValueError:
    print("Please enter a valid integer.")
except AssertionError as e:
    print(e)
except ZeroDivisionError:
    print("Division by zero is not allowed.")
finally:
    print("Execution completed.")
